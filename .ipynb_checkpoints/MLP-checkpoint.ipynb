# %% [markdown]
# O notebook a seguir é o projeto de MLP da cadeira de Sistemas Inteligentes. Para sua execução, irei usar a biblioteca MLP do SKLearn, e farei uma análise preliminar dos dados visando criar o melhor modelo possível.
#
# # O dataset
#
# Será usado um dataset de conjunto de sintomas de lombalgia, disponibilizado no Kaggle. Vou começar importando o dataset e vendo algumas propriedades:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import seaborn as sns

# %%
df = pd.read_csv('Dataset_spine.csv')

# %%
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
#
#                                          Unnamed: 13
# 0                                                NaN
# 1                                                NaN
# 2  Prediction is done by using binary classificat...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# Analisando a coluna 13, para verificar se há alguma necessidade de mantê-la ou podemos dropar:

# %%
df['Unnamed: 13'].value_counts()
# Out:
#  Attribute11=sacrum_angle(numeric)                    1
# Attribute class {Abnormal, Normal}                    1
# Attribute1  = pelvic_incidence  (numeric)             1
# Attribute6 = degree_spondylolisthesis (numeric)       1
#  Attribute9= thoracic_slope(numeric)                  1
#  Attribute7= pelvic_slope(numeric)                    1
#  Attribute12= scoliosis_slope(numeric)                1
# Attribute4 = sacral_slope (numeric)                   1
# Prediction is done by using binary classification.    1
#  Attribute10= cervical_tilt(numeric)                  1
# Attribute2 = pelvic_tilt (numeric)                    1
# Attribute3 = lumbar_lordosis_angle (numeric)          1
# Attribute5 = pelvic_radius (numeric)                  1
#  Attribute8= Direct_tilt(numeric)                     1
# Name: Unnamed: 13, dtype: int64

# %%
df['Unnamed: 13'].isna().value_counts()
# Out:
# True     296
# False     14
# Name: Unnamed: 13, dtype: int64

# %%
list(df['Unnamed: 13'].isna().value_counts())[0]/len(df)
# Out:
# 0.9548387096774194

# %% [markdown]
# A coluna conta com 95% de NAs, todos valores de texto livre, portanto, não há relevância preditiva para essa coluna e dessa forma ela será retirada do dataset:

# %%
df.drop(['Unnamed: 13'], axis=1, inplace=True)

# %% [markdown]
# Agora vou analisar os tipos dos dados e em seguida, fazer as modificações necessárias para deixar tudo númerico em função do modelo de previsão:

# %%
df.dtypes
# Out:
# Col1         float64
# Col2         float64
# Col3         float64
# Col4         float64
# Col5         float64
# Col6         float64
# Col7         float64
# Col8         float64
# Col9         float64
# Col10        float64
# Col11        float64
# Col12        float64
# Class_att     object
# dtype: object

# %%
df.Class_att.value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: Class_att, dtype: int64

# %% [markdown]
# É necessário mudar apenas o tipo de dado da coluna Class_att, que é o target:

# %%
df.Class_att = df.Class_att.replace({'Abnormal': 0, 'Normal': 1})

# %%
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12  Class_att
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123          0
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102          0
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221          0
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329          0
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171          0

# %% [markdown]
# Também foi mostrado a diferença entre casos anormais e normais que ocorreram no dataset. Não há um grande desbalanceamento:

# %%
plt.figure(figsize=(15,10))
plt.title('Gráfico em barra da quantidade de casos normais e anormais')
df.Class_att.value_counts().plot(kind='bar', color=list('rb'))
plt.show()

# %% [markdown]
# Agora farei uma análise de correlação, começando pelo scatterplot das features:

# %%
sns.set(style='ticks', color_codes=True)
sns.pairplot(df,kind='reg')
plt.show()

# %% [markdown]
# O gráfico acima dá um panorama geral da correlação, mas ela pode ser vista melhor com uma matriz de correlação:

# %%
cols = df.columns.values

corr = df.corr(method='pearson')
corr
# Out:
#                Col1      Col2      Col3      Col4      Col5      Col6  \
# Col1       1.000000  0.629199  0.717282  0.814960 -0.247467  0.638743
# Col2       0.629199  1.000000  0.432764  0.062345  0.032668  0.397862
# Col3       0.717282  0.432764  1.000000  0.598387 -0.080344  0.533667
# Col4       0.814960  0.062345  0.598387  1.000000 -0.342128  0.523557
# Col5      -0.247467  0.032668 -0.080344 -0.342128  1.000000 -0.026065
# Col6       0.638743  0.397862  0.533667  0.523557 -0.026065  1.000000
# Col7       0.043290  0.008852  0.029486  0.048988  0.015767  0.085925
# Col8      -0.078411 -0.072119 -0.112939 -0.046914  0.063433 -0.063812
# Col9      -0.089740 -0.063394 -0.063582 -0.067968  0.060477 -0.057286
# Col10      0.016750  0.028931  0.063875 -0.000063 -0.039800  0.056576
# Col11      0.019240  0.032859  0.057199  0.000207  0.029738  0.023021
# Col12     -0.007251 -0.056550 -0.049054  0.032853 -0.030145 -0.041023
# Class_att -0.353336 -0.326063 -0.312484 -0.210602  0.309857 -0.443687
#
#                Col7      Col8      Col9     Col10     Col11     Col12  \
# Col1       0.043290 -0.078411 -0.089740  0.016750  0.019240 -0.007251
# Col2       0.008852 -0.072119 -0.063394  0.028931  0.032859 -0.056550
# Col3       0.029486 -0.112939 -0.063582  0.063875  0.057199 -0.049054
# Col4       0.048988 -0.046914 -0.067968 -0.000063  0.000207  0.032853
# Col5       0.015767  0.063433  0.060477 -0.039800  0.029738 -0.030145
# Col6       0.085925 -0.063812 -0.057286  0.056576  0.023021 -0.041023
# Col7       1.000000  0.012694 -0.011770  0.088017  0.060743 -0.073893
# Col8       0.012694  1.000000  0.009887  0.072738 -0.037428 -0.024021
# Col9      -0.011770  0.009887  1.000000  0.052451  0.011354  0.009541
# Col10      0.088017  0.072738  0.052451  1.000000  0.057451  0.021243
# Col11      0.060743 -0.037428  0.011354  0.057451  1.000000  0.015337
# Col12     -0.073893 -0.024021  0.009541  0.021243  0.015337  1.000000
# Class_att -0.055865  0.039591  0.049354 -0.100044 -0.026887  0.069315
#
#            Class_att
# Col1       -0.353336
# Col2       -0.326063
# Col3       -0.312484
# Col4       -0.210602
# Col5        0.309857
# Col6       -0.443687
# Col7       -0.055865
# Col8        0.039591
# Col9        0.049354
# Col10      -0.100044
# Col11      -0.026887
# Col12       0.069315
# Class_att   1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
plt.show()

# %% [markdown]
# A coluna target tem correlação próxima a zero com quase todas as features, o que mostra que será difícil conseguir um modelo que traga uma boa previsão.

# %% [markdown]
# # O modelo
#
# Será feito um MLP usando a biblioteca SKLearn, também farei variação de parâmetros e o scale do dataset.

# %%
X = df[df.columns[0:-1]]
y = df[['Class_att']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
scaler = preprocessing.StandardScaler()

X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
mlp = MLPClassifier(random_state=42)
mlp.fit(X_train_std, y_train.values.ravel())
# Out:
# /home/sergio/.local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(random_state=42)

# %%
print('Train score: {:.3f}'.format(mlp.score(X_train_std, y_train)))
print('Test score: {:.3f}'.format(mlp.score(X_test_std, y_test)))
# Out:
# Train score: 0.927
# Test score: 0.795

# %% [markdown]
# O modelo apresenta perfeição quando testado em cima do treino. Isso é um forte indicador de overfit, ainda mais porque há uma enorme diferença entre o desempenho no dataset de treino e no de teste. Para tentar resolver esse problema, irei fazer a variação de parâmetros.
#
# ## Variação de Parâmetros
#
# Aqui, irei usar grid search e cross-validation. Grid search é uma técnica de variação de parâmetros que itera por diversos possíveis parâmetros diferentes, e, para testar o desempenho, usarei validação cruzada, que testa em uma parte aleatória do dataset como o modelo está performando.
#
# A variação de parâmetros do MLP será feita em três parâmetros:
#
# - Tamanho das hidden layers: irei testar diferentes formatos de camadas, a primeira com três camadas de 50 neurons, a segunda com duas camadas de 50 neurons e uma de 100 neurons, e a última com uma única camada de 100 neurons.
# - Função de ativação: irei testar entre tanh e relu
# - Alpha: aqui é o parâmetro de regularização, que vai controlar a influência de cada feature. Irei variar entre 0.05 e 0.0001.

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'alpha': [0.0001, 0.05],
}

clf = GridSearchCV(mlp, params, n_jobs=-1, cv=3)
clf.fit(X_train_std, y_train.values.ravel())
# Out:
# /home/sergio/.local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# GridSearchCV(cv=3, estimator=MLPClassifier(random_state=42), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.05],
#                          'hidden_layer_sizes': [(50, 50, 50), (50, 100, 50),
#                                                 (100,)]})

# %%
print('Train score: {:.3f}'.format(clf.score(X_train_std, y_train.values.ravel())))
print('Test score: {:.3f}'.format(clf.score(X_test_std, y_test)))
# Out:
# Train score: 0.879
# Test score: 0.821

# %% [markdown]
# O modelo melhorou bastante após o grid search, tendo o score de teste aumentado e o de treino mais próximo dele, o que indica que não há overfit. Um gráfico interessante do mlp é analisar a participação de cada uma das features usando o coefs_ do sklearn.

# %%
clf.best_params_
# Out:
# {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,)}

# %%
mlp = MLPClassifier(activation='tanh', alpha= 0.0001, hidden_layer_sizes= (100,), random_state=42)
mlp.fit(X_train_std, y_train.values.ravel())
# Out:
# /home/sergio/.local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='tanh', random_state=42)

# %%
plt.figure(figsize=(15, 5))
plt.imshow(mlp.coefs_[0], interpolation='none', cmap='viridis')
plt.yticks(range(len(X.columns)), X.columns)
plt.xlabel("Columns in weight matrix")
plt.ylabel("Input feature")
plt.colorbar()

# %% [markdown]
# Esse gráfico mostra o quanto cada feature está impactando no resultado do modelo, por meio da participação na matriz de pesos da MLP.
